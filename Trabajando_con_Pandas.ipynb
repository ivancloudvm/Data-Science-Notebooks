# %% [markdown]
# ivancloudvm@gmail.com
#
# <center>
#     <img src="https://www.freecodecamp.org/news/content/images/2020/07/pandas-logo.png" width="500"   />
# </center>

# %% [markdown]
# # Trabajando con la libreria Pandas
#
# La siguiente parte está basada en:
#
# https://datacarpentry.org/python-ecology-lesson-es/aio.html
#
# https://pandas.pydata.org/docs/pandas.pdf
#
# https://www.youtube.com/playlist?list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y
#
# https://www.youtube.com/watch?v=8ASjvOIyyl8&t=968s&ab_channel=LeonardoKuffo   #Pandas en 30 min

# %%
import pandas as pd
import numpy as np

surveys_df = pd.read_csv("surveys.csv")               #lectura de archivos .csv (comma separated values)

surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %% [markdown]
# Para ver el tipo de datos en cada columna usamos el método:

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %% [markdown]
# Para ver el índice de las columnas del dataframe:

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %% [markdown]
# El siguiente metodo muestra una tupla de las dimensiones de la tabla, (filas, columnas):

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %% [markdown]
# El metodo head() muestra en encabezado del dataframe y las primeras 5 filas con sus respectivas columnas:

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# El argumento de head() indica el número de filas a mostrar:

# %%
surveys_df.head(10)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %% [markdown]
# tail() muestra las ultimas filas del dataframe, también se puede indicar en su argumento el numero de fila a mostrar:

# %%
surveys_df.tail(3)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %% [markdown]
#  La función pd.unique nos dice los distintos valores presentes en la columna species_id.

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %% [markdown]
# ### Ejercicio
# 1 Crear una lista de los IDs de los sitios (“plot_id”) que están en los datos del censo. Llamamemos a esta lista site_names. ¿Cuántos sitios hay en los datos?, ¿cuántas especies hay en los datos?
#
# 2 ¿Cuál es la diferencia entre len(site_names) y surveys_df['plot_id'].nunique()?

# %%
site_names = pd.unique(surveys_df["plot_id"])

print(site_names)

#Cuantos sitios hay en los datos?: 
print(len(site_names))

#2 La diferencia es que len muestra el numero de datos en la lista, y la función unique() nos da una lista de los distintos
#  datos en la columna.
# Out:
# [ 2  3  7  1  6  5  8  4 11 14 15 13  9 10 17 16 20 23 18 21 22 19 12 24]
# 24

# %% [markdown]
# Podemos calcular algunas estadísticas básica de todos los datos en una columna usando el siguiente método:

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %% [markdown]
# También podemos extraer una métrica en particular:

# %%
(surveys_df['weight'].min(),
surveys_df['weight'].max(),
surveys_df['weight'].mean(),
surveys_df['weight'].std(),
surveys_df['weight'].count())
# Out:
# (4.0, 280.0, 42.672428212991356, 36.63125947458399, 32283)

# %% [markdown]
# Pero si nosotros queremos extraer información por una o más variables, por ejemplo sexo, podemos usar el método .groupby de Pandas. Una vez que creamos un DataFrame groupby, podemos calcular estadísticas por el grupo de nuestra elección.

# %%
# Datos agrupados por sexo
grouped_data = surveys_df.groupby('sex')

# %% [markdown]
# La función <code>describe()</code> de Pandas regresa estadísticas descriptivas incluyendo: media, meadiana, máx, mín, std y conteos para una columna en particular de los datos. La función describe solo regresa los valores de estas estadísticas para las columnas numéricas.

# %%
# Estadísticas para todas las columnas numéricas por sexo
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.583047  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.392668  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
# Regresa la media de cada columna numérica por sexo
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %% [markdown]
# ### Ejercicio
#
# 1 ¿Cuántos individuos son hembras F y cuántos son machos M?
#
# 2 Qué pasa cuando agrupas sobre dos columnas usando el siguiente enunciado y después tomas los valores medios:
#
# - grouped_data2 = surveys_df.groupby(['plot_id','sex'])
#
# - grouped_data2.mean()
#
# 3 Calcula las estadísticas descriptivas del peso para cada sitio. Sugerencia: puedes usar la siguiente sintaxis para solo crear las estadísticas para una columna de tus datos by_site['weight'].describe()

# %% [markdown]
# ### Solución
#
# \# 1
#
# Primero creamos dataframes para sexo M y otro para sexo F, esto se puede hacer de dos maneras diferentes:
#
# - usando el método drop() especificando que queremos quitar del dataframe inicial los datos que tengan sex = M
#
# - filtrando los datos usando la notación: data_frame[data_frame.condicion_de_la_columna]

# %%
#Eliminamos a las hombres del dataframe:
femalesdf = surveys_df.drop(surveys_df[surveys_df['sex']== "M"].index)

#Eliminamos a las mujeres del dataframe:
malesdf = surveys_df.drop(surveys_df[surveys_df['sex']== "F"].index)

#Eliminamos los datos que no tienen sexo:
withsexdf = surveys_df.dropna()            #elimina las filas en donde al menos un elemento es NaN. 

#Podemos intercambiar NaN por algun valor en especifico, por ejemplo:
filldf = surveys_df.fillna(0)

# %%
filldf
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL   M             32.0
# 1              2      7   16  1977        3         NL   M             33.0
# 2              3      7   16  1977        2         DM   F             37.0
# 3              4      7   16  1977        7         DM   M             36.0
# 4              5      7   16  1977        3         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35544      35545     12   31  2002       15         AH   0              0.0
# 35545      35546     12   31  2002       15         AH   0              0.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
# 35548      35549     12   31  2002        5          0   0              0.0
#
#        weight
# 0         0.0
# 1         0.0
# ...

# %% [markdown]
# Podemos intercambiar valores NaN por otros especificando la columna y el valor a intercambiar en estas:

# %%
filldf_c = surveys_df.fillna({"sex": "NA", "weight": 0})

filldf_c
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL   M             32.0
# 1              2      7   16  1977        3         NL   M             33.0
# 2              3      7   16  1977        2         DM   F             37.0
# 3              4      7   16  1977        7         DM   M             36.0
# 4              5      7   16  1977        3         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35544      35545     12   31  2002       15         AH  NA              NaN
# 35545      35546     12   31  2002       15         AH  NA              NaN
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
# 35548      35549     12   31  2002        5        NaN  NA              NaN
#
#        weight
# 0         0.0
# 1         0.0
# ...

# %% [markdown]
# Filtrando datos obtenemos los siguientes dataframes (más conveniente):

# %%
femalesdf = surveys_df[surveys_df.sex == "F"]
malesdf = surveys_df[surveys_df.sex == "M"]

# %%
#Numero de especies de sexo masculino:
malesdf.sex.count()
# Out:
# 17348

# %%
#Número de especies de sexo femenino:
femalesdf.sex.count()
# Out:
# 15690

# %% [markdown]
# Nótese que la siguiente expresion es booleana:

# %%
surveys_df.sex == "F"
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 35544    False
# 35545    False
# 35546     True
# 35547    False
# 35548    False
# Name: sex, Length: 35549, dtype: bool

# %% [markdown]
# ---
#
# Metodo .T sirve para transponer filas por columnas:
#
# ---

# %%
#2
grouped_data2 = surveys_df.groupby(['plot_id','sex'])

grouped_data2.describe()
# Out:
#             record_id                                                         \
#                 count          mean           std     min       25%      50%
# plot_id sex
# 1       F       848.0  18390.384434  10469.790852     9.0   8783.50  19182.5
#         M      1095.0  17197.740639   9911.570595     6.0   8638.00  17043.0
# 2       F       970.0  17714.753608  10300.015076     3.0   9580.25  18104.5
#         M      1144.0  18085.458042  10555.331260     1.0   8653.00  19024.5
# 3       F       893.0  19888.783875   9352.010884    17.0  12963.00  20051.0
#         M       840.0  20226.767857   9680.405281     2.0  13184.25  20904.5
# 4       F       872.0  17489.205275  10314.252887    16.0   8733.00  17441.5
#         M      1030.0  18493.841748   9808.465995   195.0  10845.00  18666.5
# 5       F       527.0  12280.793169   8296.352658    11.0   5445.50  10916.0
#         M       586.0  12798.426621   8457.974266    98.0   5994.75  11203.0
# ...

# %%
#3 

by_site = surveys_df.groupby("plot_id")

by_site["weight"].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %% [markdown]
# ## Filtrando filas
#
# Antes vimos como filtrar columnas, ahora veamos cómo filtrar filas y se pueden usar condiciones para filtrar:

# %%
# Por ejemplo los datos que tengan un hindfoot_length mayor a 30:

surveys_df[surveys_df["hindfoot_length"] > 30]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL   M             32.0
# 1              2      7   16  1977        3         NL   M             33.0
# 2              3      7   16  1977        2         DM   F             37.0
# 3              4      7   16  1977        7         DM   M             36.0
# 4              5      7   16  1977        3         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35533      35534     12   31  2002       14         DM   M             37.0
# 35534      35535     12   31  2002       14         DM   M             37.0
# 35535      35536     12   31  2002       14         DM   F             35.0
# 35536      35537     12   31  2002       14         DM   F             36.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 0         NaN
# 1         NaN
# ...

# %% [markdown]
# En caso de querer que se cumpla **más de una condición** es posible usar operadores lógicos pero **IMPORTANTE**: la sintaxis en Pandas no es la misma que en Python, en Pandas debemos usar los operadores **& para and , | para or**  además de **encerrar en parentesis cada condición**. Por ejemplo:

# %%
survcond = surveys_df[(surveys_df["hindfoot_length"] > 30) & (surveys_df["weight"] > 35)]

survcond
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# 67            68      8   19  1977        8         DO   F             32.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35533      35534     12   31  2002       14         DM   M             37.0
# 35534      35535     12   31  2002       14         DM   M             37.0
# 35535      35536     12   31  2002       14         DM   F             35.0
# 35536      35537     12   31  2002       14         DM   F             36.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %% [markdown]
# Podemos filtrar los datos que contengan alguna cadena en especifico de alguna columna en especifico:
#
# **IMPORTANTE: Si la columna tiene datos NaN el siguiente comando arrojará error**

# %%
#usé el siguiente df ya que no contiene datos NaN en la columna sex
withsexdf[withsexdf["sex"].str.contains("F")]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 67            68      8   19  1977        8         DO   F             32.0
# 69            70      8   19  1977        3         OX   F             21.0
# 70            71      8   19  1977        7         DM   F             36.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35539      35540     12   31  2002       15         PB   F             26.0
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
#
#        weight
# 64       29.0
# 65       46.0
# ...

# %%
#Podemos crear otra columna con los datos de una columna existente:

#creamos una función para aplicaar a cada elemento de la columna:
def peso_2(peso):
    peso2 = peso * 2
    return peso2


surveys_df["weight*2"] = surveys_df["weight"].apply(peso_2)

surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight  weight*2
# ...

# %% [markdown]
# Si queremos usar más de una columna para crear otra columna:

# %%
def sumafilas(fila):
    result = fila["year"] + fila["day"]
    return result


surveys_df["Suma"] = surveys_df.apply(sumafilas, axis= 1)

surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight  weight*2  Suma
# 0     NaN       NaN  1993
# 1     NaN       NaN  1993
# 2     NaN       NaN  1993
# 3     NaN       NaN  1993
# 4     NaN       NaN  1993

# %% [markdown]
# Si queremos borrar alguna columna usamos el método <code>.drop()</code> indicando el nombre de la columna, seguido por el eje, y luego la opción inplace:

# %%
surveys_df.drop(["weight*2", "Suma"], axis = 1, inplace = True)

surveys_df.head()   #aquí ya se borraron las columnas weight*2 y Suma
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# Ahora contemos el número de muestras de cada especie. Podemos hacer esto de distintas maneras, pero usaremos groupby combinada con el método count()

# %%
# Cuenta el número de muestras por especie tomando en cuenta sólo la columna record_id

species_counts = surveys_df.groupby('species_id')['record_id'].count()

print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
# Filtrando sólo la fila "DO": 
surveys_df.groupby('species_id')['record_id'].count()["DO"]
# Out:
# 3027

# %% [markdown]
# ¿Qué otra manera hay de crear una lista de especies y asociarle count de las muestras de los datos? Sugerencia: puedes hacer ejecutar las funciones count, min, etc. en un DataFrame groupby de la misma manera de la que se hace en un DataFrame

# %%
# Se crea un dataframegroupby por species_id , se cuenta el número de datos en cada columna, 
# luego se puede especificar la columna que queremos filtrar y luego especificar la fila...

surveys_df.groupby('species_id').count()["sex"]["BA"]
# Out:
# 45

# %% [markdown]
# A un dataframe groupby le podemos aplicar varias funciones de agregación usando el metodo .agg():

# %%
por_especie = surveys_df.groupby("species_id")

por_especie.agg({"hindfoot_length": "mean", "weight": "sum"})
# Out:
#             hindfoot_length    weight
# species_id
# AB                      NaN       0.0
# AH                33.000000       0.0
# AS                      NaN       0.0
# BA                13.000000     387.0
# CB                      NaN       0.0
# CM                      NaN       0.0
# CQ                      NaN       0.0
# CS                      NaN       0.0
# CT                      NaN       0.0
# CU                      NaN       0.0
# CV                      NaN       0.0
# DM                35.982351  442886.0
# DO                35.607551  141920.0
# DS                49.948874  281586.0
# DX                      NaN       0.0
# NL                32.294227  183451.0
# OL                20.532609   30628.0
# OT                20.267415   52338.0
# OX                19.125000     126.0
# PB                26.115922   89178.0
# PC                      NaN       0.0
# PE                20.195545   27199.0
# PF                15.583389   12265.0
# ...

# %% [markdown]
# Ahora graficamos las species_id vs record_id, es decir, cuantas especies se capturaron de cada tipo.

# %%
# %matplotlib inline

species_counts.plot(kind='bar');

# %% [markdown]
# También podemos ver cuantos animales fueron capturados por sitio:

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()

# También grafiquemos eso
total_count.plot(kind='bar');

# %% [markdown]
# ## Ejercicio
#
# 1- Crea una gráfica del promedio de peso de las especies por sitio.
#
# 2- Crea una gráfica del total de machos contra el total de hembras para todo el conjunto de datos.

# %% [markdown]
# ### Solución

# %%
# 1 

peso_prom = surveys_df.groupby("species_id")["weight"].mean()

peso_prom.plot(kind = "bar");

# %%
#2 

columnasplot = ["record_id", "plot_id", "species_id", "hindfoot_length", "weight"]
sexovs = surveys_df.groupby("sex")[columnasplot].count()
sexovs.plot(kind= "bar");

# %% [markdown]
# Crea una gráfica de barras apiladas con el peso en el eje Y, y la variable de apilamiento que sea el sexo. La gráfica debe mostrar el peso total por sexo para cada sitio. Algúnos tips que te pueden ayudar a resolver el reto son los siguientes:
#
# Para mayor información en gráfica con Pandas, visita la siguiente liga: https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# Puedes usar el siguiente código para crear una gráficad de barras apiladas pero los datos para apilar deben de estar en distintas columnas. Aquí hay un pequeño ejemplo con algunos datos donde ‘a’, ‘b’ y ‘c’ son los grupos, y ‘one’ y ‘two’ son los subgrupos.

# %%
d = {'one' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']),'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
pd.DataFrame(d)
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
# Graficar datos apilados de modo que las columnas 'one' y 'two' estén apiladas
my_df = pd.DataFrame(d)
my_df.plot(kind='bar',stacked=True,title="The title of my graph")

# %%
dfsex = {'M' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
         'F': pd.Series([1., 2., 3., 4.], 
                          index=['a', 'b', 'c', 'd'])}

pd.DataFrame(dfsex)
# Out:
#      M    F
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %% [markdown]
# ### Solución:

# %%
# Se agrupan los datos por sitio y por sexo:
by_site_sex = surveys_df.groupby(['plot_id','sex'])

# Se suman los pesos de machos y hembras en cada sitio:
site_sex_count = by_site_sex['weight'].sum()

# Se visualiza como:
site_sex_count.head(10)
# Out:
# plot_id  sex
# 1        F      38253.0
#          M      59979.0
# 2        F      50144.0
#          M      57250.0
# 3        F      27251.0
#          M      28253.0
# 4        F      39796.0
#          M      49377.0
# 5        F      21143.0
#          M      23326.0
# Name: weight, dtype: float64

# %% [markdown]
# Ahora usaremos .unstack() en los datos agrupados para entender como el peso total de cada sexo contribuye a cada sitio.

# %%
site_sex_count.unstack()
# Out:
# sex            F        M
# plot_id
# 1        38253.0  59979.0
# 2        50144.0  57250.0
# 3        27251.0  28253.0
# 4        39796.0  49377.0
# 5        21143.0  23326.0
# 6        26210.0  27245.0
# 7         6522.0   6422.0
# 8        37274.0  47755.0
# 9        44128.0  48727.0
# 10        2359.0   2776.0
# 11       34638.0  43106.0
# 12       51825.0  57420.0
# 13       24720.0  30354.0
# 14       32770.0  46469.0
# 15       12455.0  11037.0
# 16        5446.0   6310.0
# 17       42106.0  48082.0
# 18       27353.0  26433.0
# 19       11297.0  11514.0
# 20       33206.0  25988.0
# 21       15481.0   9815.0
# 22       34656.0  35363.0
# 23        3352.0   3883.0
# 24       22951.0  18835.0

# %% [markdown]
# Ahora creamos una gráfica de barras apilada con los datos donde el peso para cada sexo es apilado por sitio.
#
# En vez de mostrarla como tabla, nosotros podemos graficar los datos apilando los datos de cada sexo como sigue:

# %%
spc = site_sex_count.unstack()

s_plot = spc.plot(kind='bar',stacked=True ,title="Total weight by site and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# # Indexación, segmentación y creación de subconjuntos a partir de DataFrames en Python
#
# ## Seleccionando datos mediante el uso de Etiquetas

# %% [markdown]
# Como se indico anteriormente, podemos seleccionar un subconjunto de un dataframe usando [] o usando la etiqueta de la columna como método:

# %%
species1 = surveys_df["species_id"]

#que es equivalente a 
species2 = surveys_df.species_id

species2.head()
# Out:
# 0    NL
# 1    NL
# 2    DM
# 3    DM
# 4    DM
# Name: species_id, dtype: object

# %% [markdown]
# Podemos pasar una lista de nombres de columnas:
#
# Si algun nombre de columna no se encuentra en el dataframe ocurrirá un error.

# %%
#el orden de los nombres es importante.
species_record = surveys_df[["record_id", "species_id"]]  

species_record.head(3)
# Out:
#    record_id species_id
# 0          1         NL
# 1          2         NL
# 2          3         DM

# %% [markdown]
# La segmentación utilizando el operador [] selecciona un conjunto de filas y/o columnas de un DataFrame. Para segmentar un conjunto de filas, usa la siguiente sintaxis: data[start:stop]

# %%
surveys_df[0:3]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
# la ultima fila:
surveys_df[-1:]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35548     NaN

# %% [markdown]
# ## iloc y loc
#
# Podemos seleccionar subconjuntos de datos, contenidos en rangos específicos de filas y columnas, usando etiquetas o indexación basada en números enteros.
#
# <code>**loc**</code> es usado principalmente para indexación **basada en etiquetas**. Permite usar números enteros pero son interpretados como una etiqueta.
#
# <code>**iloc**</code> es usado para indexación **basada en números enteros**.

# %%
# iloc[segmentación de fila, segmentación de columna]
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
# Selecciona todas las columnas para las filas con índices entre 0 y 10
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
# ¿Qué salida produce el la siguiente instrucción?
surveys_df.loc[0, ['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
# ¿Qué pasa cuando ejecutas el siguiente código?
surveys_df.loc[[0, 10, 35548], :]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 10            11      7   16  1977        5         DS    F             53.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 10        NaN
# 35548     NaN

# %% [markdown]
# Podemos seleccionar un dato específico utilizando la la intersección de una fila y una columna dentro del DataFrame, junto con la indexación basada en números enteros iloc:
#
# Sintaxis para encontrar un dato especifico dentro de un `DataFrame` utilizando indexación `iloc`: <code>dat.iloc[fila, columna]</code>

# %%
surveys_df.iloc[2, 6]
# Out:
# 'F'

# %%
surveys_df.iloc[35546, 5]
# Out:
# 'RM'

# %% [markdown]
# ## Metodo .isin()
#
# ### Desafío - Consultas
#
# 1 Selecciona un subconjunto de filas, en el DataFrame surveys_df, que contenga datos desde el año 1999 y que contenga valores en weight menores o iguales a 8. ¿Cuántas filas obtuviste como resultado? ¿Cuántas filas obtuvo tu compañera?
#
# Puedes usar el metodo **isin** de Python para hacer una consulta a un DataFrame, basada en una lista de valores según se muestra a continuación:  surveys_df[surveys_df['species_id'].isin([listGoesHere])]
#
#
# 2 Usa la función isin para encontrar todos los plots que contienen una especie en particular en el DataFrame surveys_df. ¿Cuántos registros contienen esos valores?
#
# 3 Experimenta con otras consultas. Crea una consulta que encuentre todas las filas con el valor de weight mayor o igual a 0.
#
# 4 El símbolo ~ puede ser usado en Python para obtener lo opuesto a los datos seleccionados que hayas especificado. Es equivalente a no esta en. Escribe una consulta que seleccione todas las filas con sex diferente de ‘M’ o ‘F’ en los datos de surveys_df.

# %%
#1
surv1999 = surveys_df[(surveys_df.year >= 1999) & (surveys_df.weight <= 8)]

#numero de filas:
print(f"Numero de filas: {surv1999.shape[0]} ")
# Out:
# Numero de filas: 55

# %%
#2
# Filtra los datos que tienen a RM como especie
specie_RM = surveys_df[surveys_df['species_id'].isin(["RM"])]

print(specie_RM.species_id.count())
# Out:
# 2609

# %%
#3
lista_pesos = surveys_df[surveys_df.weight >= 0]

lista_pesos.head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62         63      8   19  1977        3         DM   M             35.0
# 63         64      8   19  1977        7         DM   M             37.0
# 64         65      8   19  1977        4         DM   F             34.0
# 65         66      8   19  1977        4         DM   F             35.0
# 66         67      8   19  1977        7         DM   M             35.0
#
#     weight
# 62    40.0
# 63    48.0
# 64    29.0
# 65    46.0
# 66    36.0

# %%
#4
#creo un dataframe donde sólo haya M en la columna sex:
onlyM = surveys_df["sex"].isin(["M"])

# uso ~ para indicar que quiero las filas que NO esten en onlyM
noM = surveys_df[~onlyM]

noM.head()
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2           3      7   16  1977        2         DM   F             37.0
# 6           7      7   16  1977        2         PE   F              NaN
# 8           9      7   16  1977        1         DM   F             34.0
# 9          10      7   16  1977        6         PF   F             20.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 2      NaN
# 6      NaN
# 8      NaN
# 9      NaN
# 10     NaN

# %% [markdown]
# ## Usando máscaras para identificar una condición específica
#
# Una máscara puede ser útil para identificar donde existe o no exite un subconjunto específico de valores - por ejemplo, NaN, o Not a Number en inglés.
#
# Para crear una máscara booleana:
#
# - Establece el criterio a ser evaluado como True o False (ej. values > 5 = True)
#
# - Python evaluará cada valor en el objeto para determinar si el valor cumple el criterio (True) o no lo cumple (False).
#
# - Python crea un objeto de salida que es de la misma forma que el objeto original, pero con un valor True o False por cada índice según corresponda.
#
# Vamos a identificar todos los lugares en los datos de survey que son null (que no existen o son NaN). Podemos usar el método ``isnull``  para lograrlo. El método isnull va a comparar cada celda con un valor null. Si un elemento tiene un valor null, se le asignará un nuevo valor de True en el objeto de salida.

# %%
pd.isnull(surveys_df)
# Out:
#        record_id  month    day   year  plot_id  species_id    sex  \
# 0          False  False  False  False    False       False  False
# 1          False  False  False  False    False       False  False
# 2          False  False  False  False    False       False  False
# 3          False  False  False  False    False       False  False
# 4          False  False  False  False    False       False  False
# ...          ...    ...    ...    ...      ...         ...    ...
# 35544      False  False  False  False    False       False   True
# 35545      False  False  False  False    False       False   True
# 35546      False  False  False  False    False       False  False
# 35547      False  False  False  False    False       False  False
# 35548      False  False  False  False    False        True   True
#
#        hindfoot_length  weight
# 0                False    True
# 1                False    True
# 2                False    True
# 3                False    True
# ...

# %% [markdown]
# Para seleccionar las filas donde hay valores null, podemos utilizar una máscara a manera de índice y obtener subconjuntos de datos así:

# %%
# Para seleccionar solamente las filas con valores NaN, podemos utilizar el método 'any()'
surveys_df[pd.isnull(surveys_df).any(axis=1)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
# ¿Qué hace el siguiente código?
empty_weights = surveys_df[pd.isnull(surveys_df["weight"])]["weight"]

#Tambien se puede escribir como:
#empty_weights = surveys_df[pd.isnull(surveys_df.weight)]["weight"]

empty_weights
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 35530   NaN
# 35543   NaN
# 35544   NaN
# 35545   NaN
# 35548   NaN
# Name: weight, Length: 3266, dtype: float64

# %% [markdown]
#  ### Desafío - Revisando todo lo aprendido
#
# 1 Crea un nuevo objeto DataFrame que solamente contenga observaciones cuyos valores en la columna sex no sean female o male. Asigna cada valor de sex en el nuevo DataFrame a un nuevo valor de ‘x’. Determina el número total de valores null en el subconjunto.
#
# 2 Crea un nuevo objeto DataFrame que contenga solo observaciones cuyos valores en la columna sex sean male o female y en los cuales el valor de weight sea mayor que 0. Luego, crea un gráfico de barra apiladas del promedio de weight, por parcela, con valores male versus female apilados por cada parcela.

# %%
#1 
sex_null = surveys_df[pd.isnull(surveys_df["sex"])]

x = sex_null["sex"]

x.shape[0]
# Out:
# 2511

# %%
#2 

femmandf = surveys_df[(~pd.isnull(surveys_df["sex"])) & (surveys_df.weight > 0)]

by_sexdf = femmandf.groupby(["plot_id","sex"])

weight_sex_mean = by_sexdf["weight"].mean()

wsm = weight_sex_mean.unstack()

s_plot = wsm.plot(kind='bar',stacked=True ,title="Mean weight by site and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# ### Cambiando tipo de datos.
#
# Es posible cambiar el tipo de dato en cada columna con el metodo `.astype()`.
#
# Por ejemplo:

# %%
# Convertir el campo record_id de integer a float
surveys_df['record_id'] = surveys_df['record_id'].astype('float64')
surveys_df['record_id'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Podemos usar el comando .dtypes para ver el tipo de datos de cada columna de un DataFrame (todos a la vez).

# %%
surveys_df['record_id'] = surveys_df['record_id'].astype('int64')

surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %% [markdown]
# Usando el método .fillna () podemos reemplazar todos los valores NaN por ceros (después de hacer una copia de los datos de modo tal de no perder nuestro trabajo):

# %%
df1 = surveys_df.copy()
# Completar todos los valores NaN con ceros
df1['weight'] = df1['weight'].fillna(0)

# %% [markdown]
# El valor promedio resulta diferente cuando los valores NaN se reemplazan con cero, comparando cuando los valores de NaN son descartados o ignorados.

# %%
df1['weight'].mean()
# Out:
# 38.751976145601844

# %% [markdown]
# Podemos completar los valores NaN con cualquier valor que elijamos. El código de abajo completa todos los Valores NaN con un promedio de los pesos.

# %%
df1['weight'] = surveys_df['weight'].fillna(surveys_df['weight'].mean())
    
df1['weight'].mean()
# Out:
# 42.67242821299182

# %% [markdown]
# ### Desafio
#
# Cuenta el número de valores perdidos por columna. Sugerencia: el método .count() te proporciona el número de observaciones que no son NA por columna. Examina el método .isnull().

# %%
#primero creo dataframes de cada uno de las columnas que solo contengan datos nulos:
record_null = surveys_df[pd.isnull(surveys_df["record_id"])]
plot_null = surveys_df[pd.isnull(surveys_df["plot_id"])]
sex_null = surveys_df[pd.isnull(surveys_df["sex"])]
species_null = surveys_df[pd.isnull(surveys_df["species_id"])]
hindfoot_length_null = surveys_df[pd.isnull(surveys_df["hindfoot_length"])]
weight_null = surveys_df[pd.isnull(surveys_df["weight"])]

#imprimo el numero de datos nulos en cada columna:
print("Nulos en record_id: ", len(record_null))
print("Nulos en plot_id: ", len(plot_null))
print("Nulos en species_id: ", len(species_null))
print("Nulos en sex_id: ", len(sex_null))
print("Nulos en hindfoot_length: ", len(hindfoot_length_null))
print("Nulos en weight: ", len(weight_null))
# Out:
# Nulos en record_id:  0
# Nulos en plot_id:  0
# Nulos en species_id:  763
# Nulos en sex_id:  2511
# Nulos en hindfoot_length:  4111
# Nulos en weight:  3266

# %% [markdown]
# ## Escribiendo datos a CSV
#
# Hemos aprendido a manipular datos para obtener los resultados deseados. Pero también hemos discutido acerca de mantener los datos que han sido manipulados separados de los datos sin procesar. Algo que podríamos estar interesados en hacer es trabajar solo con las columnas que tienen datos completos. Primero, recarguemos los datos para no mezclar todas nuestras manipulaciones anteriores.

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
#vamos a eliminar todas las filas que contienen valores nulos.
df_na = surveys_df.dropna()
df_na
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %% [markdown]
# Ahora podemos usar el comando to_csv para exportar un DataFrame a formato CSV. Ten en cuenta que el código que se muestra a continuación por defector guardará los datos en el directorio de trabajo en el que estamos parados. Podemos guardarlo en otra carpeta agregando el nombre de la carpeta y una barra inclinada antes del nombre del archivo: df.to_csv('foldername/out.csv'). Usamos index = False para que Pandas no incluya el número de índice para cada fila.

# %%
# Escribir DataFrame a CSV
df_na.to_csv('surveys_complete.csv', index=False)

# %% [markdown]
# # Combinando DataFrames con Pandas
#
# En muchas situations del “mundo real”, los datos que queremos usar proceden de múltiples archivos. Frecuentemente necesitamos combinar estos archivos en un uniquo DataFrame para analizar los datos. El paquete pandas proporciona varios métodos de combinar DataFrames incluyendo merge y concat.
#
# Para trabajar en los ejemplos abajo, necesitamos primero cargar los archivos de species y surveys dentro de pandas DataFrames. En Python:

# %%
surveys_df = pd.read_csv("surveys.csv",
                         keep_default_na=False, na_values=[""])

species_df = pd.read_csv("species.csv",
                         keep_default_na=False, na_values=[""])

species_df.head(3)
# Out:
#   species_id             genus     species    taxa
# 0         AB        Amphispiza   bilineata    Bird
# 1         AH  Ammospermophilus     harrisi  Rodent
# 2         AS        Ammodramus  savannarum    Bird

# %% [markdown]
# ## Concatenando DataFrames
#
# Podemos usar la función concat en pandas para agregar columnas o filas de un DataFrame a otro. Tomemos dos subconjuntos de nuestros datos para ver cómo esto trabaja.

# %%
# Lee las primeras 10 líneas de la tabla de encuestas.
survey_sub = surveys_df.head(10)
# Agarra las últimas 10 filas
survey_sub_last10 = surveys_df.tail(10)
# Restablecer los valores de índice a la segunda __DataFrame__ adjunta correctamente
survey_sub_last10=survey_sub_last10.reset_index(drop = True)
# drop=True esta opción evita agregar una nueva columna llamada índice con valores de índice antiguos

survey_sub_last10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %% [markdown]
# Cuando concatenamos DataFrames, necesitamos especificar el eje. axis=0 dice pandas para apilar el segundo DataFrame debajo del primero. Será automáticamente detecta si los nombres de las columnas son iguales y se apilarán en consecuencia. axis=1 apilará las columnas en el segundo DataFrame a la DERECHA del primer DataFrame. Para apilar los datos verticalmente, necesitamos asegurarnos de que tenemos las mismas columnas y el formato de columna asociado en los dos datasets. Cuando apilamos horizontalmente, queremos asegurarnos de que lo que estamos haciendo tiene sentido (es decir, los datos son relacionados de alguna manera).

# %%
# Apilar los __DataFrames__ uno encima del otro
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# Coloque los __DataFrames__ de lado a lado
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %% [markdown]
#  Los índices de fila para los dos data frames survey_sub y survey_sub_last10 se han repetido. Podemos reindexar el nuevo data frame usando el método reset_index().

# %%
vertical_stack = vertical_stack.reset_index(drop = True)

vertical_stack
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %% [markdown]
# ## Escribiendo datos a CSV
# Podemos usar el comando to_csv para exportar un DataFrame en formato CSV. Nota que el código a continuación guardará los datos por defecto en el directorio de trabajo corriente. Podemos guárdelo en un directorio diferente agregando el nombre de la carpeta y una barra al archivo vertical_stack.to_csv ('foldername/out.csv'). Usamos el ‘índice = Falso’ para que pandas no incluye el número de índice para cada línea.

# %%
# Escribe el __DataFrame__ a CSV
vertical_stack.to_csv('vertical_stackdf.csv', index=False)

# %% [markdown]
#  Intenta subirlo de vuelta a Python para asegurarte se importa correctamente.

# %%
# Para los memes lee nuestro archivo en Python y asegúrese de que todo se vea bien.
new_output = pd.read_csv('vertical_stackdf.csv', keep_default_na=False, na_values=[""])

new_output
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# ...

# %% [markdown]
# ### Desafio
# En la carpeta de datos, hay dos archivos de datos de encuestas: survey2001.csv y survey2002.csv: https://figshare.com/articles/Portal_Project_Teaching_Database/1314459.
#
# Lee los datos en Python y combina los archivos para hacer un DataFrame nuevo. Crea una gráfica del peso promedio de la parcela, plot_id, por año agrupada por sexo. Exporta tus resultados como CSV y asegúrate de que se lean correctamente en Python.

# %%
# Se crea un df con los datos:
combdf =pd.read_csv("combined.csv")

#Se obtiene un df con los datos filtrados:
withsexdf = combdf[(~pd.isnull(combdf["sex"])) & (combdf.weight > 0)]

#Se agrupa de acuerdo al eje x:
agrupadosdf = withsexdf.groupby(["plot_id","year","sex"])

weight_sex_year = agrupadosdf["weight"].mean()

wsy = weight_sex_year.unstack()

weight_sex_year
# Out:
# plot_id  year  sex
# 1        1977  F      41.428571
#                M      34.625000
#          1978  F      82.666667
#                M      84.083333
#          1979  F      43.625000
#                         ...
# 24       2000  M      28.666667
#          2001  F      40.750000
#                M      91.500000
#          2002  F      30.200000
#                M      81.583333
# Name: weight, Length: 1223, dtype: float64

# %% [markdown]
# Podemos crear el mismo dataframe usando el metodo .pivot_table():

# %%
dfs = withsexdf.pivot_table(values = "weight", index = ["plot_id", "year"], columns = "sex")

dfs
# Out:
# sex                   F           M
# plot_id year
# 1       1977  41.428571   34.625000
#         1978  82.666667   84.083333
#         1979  43.625000   91.764706
#         1980  33.620690  104.000000
#         1981  48.607143   97.360000
# ...                 ...         ...
# 24      1998  30.636364   40.350000
#         1999  95.250000   18.000000
#         2000  26.857143   28.666667
#         2001  40.750000   91.500000
#         2002  30.200000   81.583333
#
# [618 rows x 2 columns]

# %%
stack_plot = wsy.plot(kind='bar',stacked=False ,title="Mean weight by site, year and sex")
stack_plot.set_ylabel("Weight")
stack_plot.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# ## Unión de Dos DataFrames
#
# Para comprender mejor las uniones, tomemos las primeras 10 líneas de nuestros datos como un subconjunto con para trabajar. Usaremos el método .head para hacer esto. También vamos a importar un subconjunto de la tabla de especies.

# %%
# Lee las primeras 10 líneas de la tabla de encuestas.
survey_sub = surveys_df.head(10)

# Importe un penqueño subconjunto de los datos de especies diseñados para esta parte de la lección.

speciesSubset = species_df.head(25)

speciesSubset.to_csv('speciesSubset.csv', index=False)

species_sub = pd.read_csv('speciesSubset.csv', keep_default_na=False, na_values=[""])

species_sub
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# ...

# %% [markdown]
# ### Identifying join keys
#
# Para identificar las claves de combinación adecuadas, primero necesitamos saber cuáles campos son compartidos entre los archivos (DataFrames). Podríamos inspeccionar los dos DataFrames para identificar estas columnas. Si tenemos suerte, los dos DataFrames tendrán columnas con el mismo nombre que también contienen los mismos datos. Si somos menos afortunados, necesitamos identificar una columna (con nombre diferente) en cada DataFrame que contiene la misma información.

# %%
species_sub.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
survey_sub.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %% [markdown]
# En nuestro ejemplo, la clave de unión es la columna que contiene el identificador de especie de dos letras, que se llama species_id.
#
# Ahora que conocemos los campos con los atributos de ID de especies comunes en cada DataFrame, estamos casi listos para unir nuestros datos. Sin embargo, porque hay diferentes tipos de uniones, también debemos decidir qué tipo de unión tiene sentido para nuestro análisis.

# %% [markdown]
# ## Uniones internas
#
# El tipo más común de unión se llama inner join (unión interna). Una combinación interna combina dos DataFrames basados en una clave de unión y devuelve un nuevo DataFrame que contiene solo aquellas filas que tienen valores coincidentes entre los dos DataFrames originales.
#
# Las uniones internas producen un DataFrame que contiene solo filas donde el valor que es el subjecto de la unión existe en las dos tablas.
#
# La función en pandas para realizar uniones se llama merge y una unión interna es la opción por defecto:

# %%
merged_inner = pd.merge(left=survey_sub,right=species_sub, left_on='species_id', right_on='species_id')
# En este caso, `species_id` es el único nombre de columna en los dos __DataFrames__, entonces si omitimos 
# los argumentos `left_on` y `right_on` todavía obtendríamos el mismo resultado

# ¿Cuál es el tamaño de los datos en el resultado?
merged_inner.shape

merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# ...

# %% [markdown]
# El resultado de una unión interna de survey_sub y species_sub es un nuevo DataFrame que contiene el conjunto combinado de columnas de survey_sub y species_sub. Solo contiene filas que tienen códigos de dos letras de especies que son iguales en el survey_sub y el species_sub DataFrames. En otras palabras, si una fila en survey_sub tiene un valor de species_id que no aparece en la species_id columna de species, no será incluida en el DataFrame devuelto por una unión interna. Del mismo modo, si una fila en species_sub tiene un valor de species_id que no aparece en la columna species_id de survey_sub, esa fila no será incluida en el DataFrame devuelto por una unión interna. **Se puede pensar esto como en teoria de grupos, la unión interna es la intersección de los dataframes relativo a una o varias columnas**.
#
# Los dos DataFrames a los que queremos unir se pasan a la función merge usando el argumento de left y right. El argumento left_on = 'species_id' le dice a merge que use la columna species_id como la clave de unión de survey_sub (el left DataFrame). De manera similar, el argumento right_on = 'species_id' le dice a merge que use la columna species_id como la clave de unión de species_sub (el right DataFrame). Para uniones internas, el orden de los argumentos left y right no importa.
#
# **El resultado merged_inner DataFrame contiene todas las columnas de survey_sub (ID de registro, mes, día, etc.), así como todas las columnas de species_sub (especies_id, género, especie y taxa)**.
#
# Date cuenta que merged_inner tiene menos filas que survey_sub. Esto es una indicación de que había filas en survey_df con valor(es) para species_id que no existen como valor(es) para species_id en species_df.

# %% [markdown]
# ### Unión izquierda
#
# ¿Qué pasa si queremos agregar información de species_sub a survey_sub sin perdiendo información de survey_sub? En este caso, utilizamos un diferente tipo de unión llamada “left outer join (unión externa izquierda)”, or a “left join (unión izquierda)”.
#
# Como una combinación interna, una unión izquierda utiliza las claves de unión para combinar dos DataFrames. Diferente a una unión interna, una unión izquierda devolverá todas las filas del left DataFrame, hasta aquellas filas cuyas claves de unión no tienen valores en el right DataFrame. Filas en el left DataFrame que faltan valores para las clave(s) de unión en el right DataFrame simplemente tendrán valores nulos (es decir, NaN o Ninguno) para las columnas en el resultante DataFrame unido.
#
# Nota: una unión izquierda todavía descartará las filas del right DataFrame que no tienen valores para la(s) clave(s) de unión en el left DataFrame.
#
# Una unión izquierda se realiza en pandas llamando a la misma función merge utilizada para unión interna, pero usando el argumento how = 'left':

# %%
merged_left = pd.merge(left=survey_sub,right=species_sub, how='left', left_on='species_id', right_on='species_id')

merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %% [markdown]
# El resultado DataFrame de una unión izquierda (merged_left) se parece mucho al resultado DataFrame de una unión interna (merged_inner) en términos de las columnas que contiene. Sin embargo, a diferencia de merged_inner, merged_left contiene el mismo número de filas como el DataFrame original survey_sub. Cuando inspeccionamos merged_left, encontramos que hay filas donde la información debería haber venido de species_sub (es decir, species_id, genus y taxa) hace falta (contienen valores de NaN):

# %%
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5          6      7   16  1977        1         PF   M             14.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight genus species taxa
# 5     NaN   NaN     NaN  NaN
# 9     NaN   NaN     NaN  NaN

# %% [markdown]
# Estas filas son aquellas en las que el valor de species_id de survey_sub (en este caso, PF) no ocurre en species_sub.

# %% [markdown]
# ### Otros tipos de unión
# La función merge de pandas admite otros dos tipos de unión:
#
# - Right (outer) join unión derecha (exterior): se invoca al pasar how = 'right' como argumento. Similar a una unión izquierda, excepto que se guardan todas las filas del right DataFrame, mientras que las filas del left DataFrame sin coincidir con los valores de las claves de unión son descartadas.
# - Full (outer) join unión completa (externa): se invoca al pasar how = 'outer' como argumento. Este tipo de unión devuelve todas las combinaciones de filas de los dos DataFrames; es decir., el DataFrame resultante estará NaN donde faltan datos en uno de los DataFrames. Este tipo de unión es muy raramente utilizado.

# %% [markdown]
# ### Challenge  1 - Distribuciones
# Cree un nuevo DataFrame uniendo los contenidos de survey.csv y Tablas species.csv. Luego calcula y crea un gráfico de la distribución de:
#
# - taxa por parcela
# - taxa por sexo por parcela
#
# ### Challenge 2 - Índice de Diversidad
# - En la carpeta de datos, hay un gráfico CSV (plots.csv) que contiene información sobre el tipo asociado con cada parcela. Usa esos datos para resumir el número de parcelas por tipo de parcela.
# - Calcula un índice de diversidad de su elección para control vs parcelas de rodamiento de roedores El índice debe considerar tanto la abundancia de especies como el número de especies. Puedes optar por utilizar el simple índice de biodiversidad descrito aquí que calcula la diversidad como:
#   - el número de especies en la parcela / el número total de individuos en la parcela = índice de biodiversidad.

# %%
#1 
#TAXA POR PARCELA

comb = pd.merge(left = surveys_df, right = species_df, left_on = "species_id", right_on = "species_id")

combgrup1 = comb.groupby(["plot_id", "taxa"])

cont_taxa = combgrup1["taxa"].count()

cont_taxa_unstacked = cont_taxa.unstack()

cont_taxa_unstacked.head(3)
# Out:
# taxa     Bird  Rabbit  Reptile  Rodent
# plot_id
# 1        11.0     2.0      NaN  1976.0
# 2        17.0     3.0      1.0  2170.0
# 3        17.0     5.0      NaN  1786.0

# %%
plot1 = cont_taxa_unstacked.plot(kind='bar',stacked=False ,title="Count taxa by site")
plot1.set_ylabel("Count")
plot1.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %% [markdown]
# Notese que el numero de roedores es demasiado alto comparado con las demas especies, por lo que optamos por quitar esa columna:

# %%
count_taxa =cont_taxa_unstacked.drop("Rodent", axis = 1)

count_taxa
# Out:
# taxa     Bird  Rabbit  Reptile
# plot_id
# 1        11.0     2.0      NaN
# 2        17.0     3.0      1.0
# 3        17.0     5.0      NaN
# 4         5.0     NaN      NaN
# 5         5.0     1.0      NaN
# 6        20.0     NaN      1.0
# 7        28.0     NaN      1.0
# 8        10.0     1.0      1.0
# 9        13.0     1.0      NaN
# 10       12.0    10.0      NaN
# 11       10.0     5.0      2.0
# 12       31.0     8.0      NaN
# 13       48.0     1.0      1.0
# 14       17.0     4.0      NaN
# 15       23.0     3.0      1.0
# 16       15.0     3.0      NaN
# 17        4.0     6.0      1.0
# 18       12.0     1.0      NaN
# 19       14.0     8.0      1.0
# 20       51.0     NaN      2.0
# 21       13.0     1.0      1.0
# 22       16.0     2.0      1.0
# 23       41.0     8.0      NaN
# 24       17.0     2.0      NaN

# %%
plot2 = count_taxa.plot(kind='bar',stacked=False ,title="Count taxa by site")
plot2.set_ylabel("Count")
plot2.set_xlabel("Plot")
# Out:
# Text(0.5, 0, 'Plot')

# %%
# taxa por sexo por parcela:

combgrup2 = comb.groupby(["plot_id","taxa", "sex"])

cont_taxa2 = combgrup2["taxa"].count()

cont_taxa_unstacked2 = cont_taxa2.unstack()

cont_taxa_unstacked2.head(4)
# Out:
# sex               F     M
# plot_id taxa
# 1       Rodent  848  1095
# 2       Rodent  970  1144
# 3       Rodent  893   840
# 4       Rodent  872  1030

# %% [markdown]
# Ya que sólo Roedores (Rodent) tienen sexo registrado, no hace falta agrupar por taxa ya que todos son roedores...

# %%
combgrup2 = comb.groupby(["plot_id", "sex"])

cont_taxa2 = combgrup2["taxa"].count()

cont_taxa_unstacked2 = cont_taxa2.unstack()

cont_taxa_unstacked2.head(4)
# Out:
# sex        F     M
# plot_id
# 1        848  1095
# 2        970  1144
# 3        893   840
# 4        872  1030

# %%
plot3 = cont_taxa_unstacked2.plot(kind='bar',stacked=True ,title="Count Rodent by sex and by site")
plot2.set_ylabel("Count")
plot2.set_xlabel("Plot")
# Out:
# Text(0.5, 17.200000000000003, 'Plot')

# %% [markdown]
# ## Bucles for

# %%
animals = ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']
for creature in animals:
    pass

print('The loop variable is now: ' + creature)
# Out:
# The loop variable is now: hippo

# %%
# Reescribe el bucle de tal forma que los animales estén separados por comas y no por una línea nueva. 
# (Pista: Puedes concatenar cadenas de caracteres usando el signo más. 
# Por ejemplo, print(string1 + string2) resulta en ‘string1string2’).
animals = ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']
listan = []

for creatures in animals:
    listan += creatures 

    
print(listan)
# Out:
# ['l', 'i', 'o', 'n', 't', 'i', 'g', 'e', 'r', 'c', 'r', 'o', 'c', 'o', 'd', 'i', 'l', 'e', 'v', 'u', 'l', 't', 'u', 'r', 'e', 'h', 'i', 'p', 'p', 'o']

# %% [markdown]
# ## Automatizando el procesamiento de datos usando bucles For
#
# Comencemos por crear un nuevo directorio en nuestra carpeta data para guardar todos estos archivos usando el módulo os

# %%
import os

##os.mkdir('yearly_files')

# %% [markdown]
# El comando os.mkdir es equivalente a escribir mkdir en la terminal. Solo para estar seguros, podemos verificar que nuestro nuevo directorio fue creado en la carpeta de trabajo:

# %%
#Notese que sí se creó la carpeta "yearly_files":
os.listdir()[-4:]
# Out:
# ['yearly_files',
#  'yearly_filesfunction_surveys11991.csv',
#  'yearly_filesfunction_surveys1991.csv',
#  '__pycache__']

# %% [markdown]
# El comando os.listdir es equivalente a usar ls en la terminal.
#
# En episodios anteriores, vimos cómo usar la librería Pandas para cargar en memoria, a través de DataFrame, información sobre las especies; vimos cómo seleccionar un subconjunto de esos datos usando ciertos criterios, y vimos también cómo escribir esa información en un archivo CSV. Escribamos un script que realiza esos tres pasos en secuencia para el año 2002:

# %%
import pandas as pd

# Cargamos los datos en un DataFrame
surveys_df = pd.read_csv('surveys.csv')

# Seleccionamos solo los datos del año 2002
surveys2002 = surveys_df[surveys_df.year == 2002]

# Escribimos el nuevo DataFrame en un archivo CSV
surveys2002.to_csv('yearly_files/surveys2002.csv')

surveys2002
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 33320    44.0
# ...

# %% [markdown]
# Para crear los archivos con los datos anuales, podemos repetir estos últimos dos comandos una y otra vez, una vez por cada año de información. Sin embargo, repetir código no es ni elegante ni práctico, y hace muy probable que introduzcamos errores en nuestro código. Queremos convertir lo que acabamos de escribir en un bucle que repita estos últimos dos comandos para cada año en nuestro dataset.
#
# Comencemos con un bucle que solamente imprima los nombres de los archivos que queremos crear - El dataset que estamos usando va desde 1977 hasta 2002, y vamos a crear un archivo por separado para cada año. Listar los nombres de los archivos es una buena estrategia, porque así podemos confirmar que nuestro bucle se está comportando como esperamos.
#
# Hemos visto que podemos iterar sobre una lista de elementos, entonces necesitamos una lista de años sobre la cual iterar. Podemos obtener los años en nuestro DataFrame con:

# %%
surveys_df['year']
# Out:
# 0        1977
# 1        1977
# 2        1977
# 3        1977
# 4        1977
#          ...
# 35544    2002
# 35545    2002
# 35546    2002
# 35547    2002
# 35548    2002
# Name: year, Length: 35549, dtype: int64

# %% [markdown]
# pero queremos solamente años únicos, y esto lo podemos obtener usando el método unique que ya hemos visto.

# %%
surveys_df['year'].unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002], dtype=int64)

# %% [markdown]
# Escribiendo esto en un bucle for obtenemos

# %%
for year in surveys_df['year'].unique():
   filename='yearly_files/surveys' + str(year) + '.csv'
   print(filename)
# Out:
# yearly_files/surveys1977.csv
# yearly_files/surveys1978.csv
# yearly_files/surveys1979.csv
# yearly_files/surveys1980.csv
# yearly_files/surveys1981.csv
# yearly_files/surveys1982.csv
# yearly_files/surveys1983.csv
# yearly_files/surveys1984.csv
# yearly_files/surveys1985.csv
# yearly_files/surveys1986.csv
# yearly_files/surveys1987.csv
# yearly_files/surveys1988.csv
# yearly_files/surveys1989.csv
# yearly_files/surveys1990.csv
# yearly_files/surveys1991.csv
# yearly_files/surveys1992.csv
# yearly_files/surveys1993.csv
# yearly_files/surveys1994.csv
# yearly_files/surveys1995.csv
# yearly_files/surveys1996.csv
# yearly_files/surveys1997.csv
# yearly_files/surveys1998.csv
# yearly_files/surveys1999.csv
# yearly_files/surveys2000.csv
# yearly_files/surveys2001.csv
# yearly_files/surveys2002.csv

# %% [markdown]
# Ahora podemos agregar el resto de pasos que necesitamos para crear archivos separados:

# %%
# Load the data into a DataFrame
surveys_df = pd.read_csv('surveys.csv')

for year in surveys_df['year'].unique():
    # Select data for the year
    surveys_year = surveys_df[surveys_df.year == year]

    # Write the new DataFrame to a CSV file
    filename = 'yearly_files/surveys' + str(year) + '.csv'
    surveys_year.to_csv(filename)

# %% [markdown]
# Mira dentro del directorio yearly_files y verifica un par de los archivos que acabaste de crear para confirmar que todo funcionó como esperabas.
#
# ## Escribiendo nombres de archivo únicos
# Nota que en el código anterior creamos un nombre de archivo único para cada año.
#
# `filename = 'yearly_files/surveys' + str(year) + '.csv'`
#
# Descompongamos las partes de este nombre:
#
# - La primera parte es simplemente un texto que especifica el directorio en el que vamos a guardar nuestro archivo (data/yearly_files/) y la primera parte del nombre del archivo (surveys): 'data/yearly_files/surveys'
# - Podemos concatenar esto con el valor de una variable, en este caso year, al usar el signo más y la variable que le queremos añadir al nombre del archivo: + str(year)
# - Por último añadimos la extensión del archivo usando otra cadena de caracteres: + '.csv'
#
# Nota que usamos comillas sencillas para añadir las cadenas de caracteres y que la variable no está entre comillas. Este código produce la cadena de caracteres data/yearly_files/surveys2002.csv que contiene tanto el path como el nombre del archivo.
#
#
# ## Desafío - Modificando bucles
# 1 - Algunas de las encuestas que guardaste tienen datos faltantes (tienen valores nulos que salen como NaN - No es un número (en inglés) - en los DataFrames y no salen en los archivos de texto). Modifica el bucle for para que las entradas que tengan valores nulos no sean incluidas en los archivos anuales.
#
# 2 - Supongamos que solo quieres revisar los datos cada cierto múltiplo de años. ¿Cómo modificarías el bucle para generar un archivo de datos cada cinco años comenzando desde 1977?
#
# 3 - En vez de separar la información por años, un colega tuyo quiere hacer el análisis separando por especies. ¿Cómo escribirías un único archivo CSV por cada especie?

# %%
#1

#cargamos un archivo 
df1977 = pd.read_csv("yearly_files/surveys1977.csv")

#quitamos las filas que tienen valores NaN:
df1977c = df1977.dropna(axis=0, inplace = False)  
# Este dataframe es el que tiene que ser guardado. Este procedimiento ser hará usando ciclo For:

# Load the data into a DataFrame
surveys_df = pd.read_csv('surveys.csv')

for year in surveys_df['year'].unique():
    # Select data for the year
    surveys_year = surveys_df[surveys_df.year == year]
    surveys_yearc = surveys_year.dropna(axis = 0 , inplace = False) 

    # Write the new DataFrame to a CSV file
    filename = 'yearly_files/surveys' + str(year) + '_noNan.csv'
    surveys_yearc.to_csv(filename)
    
#Notese que se crearon nuevos archivos dentro de la carpeta yearly_files:
os.listdir('yearly_files')[0:6]
# Out:
# ['function_surveys11991.csv',
#  'function_surveys11992.csv',
#  'function_surveys11993.csv',
#  'function_surveys11994.csv',
#  'function_surveys11995.csv',
#  'function_surveys11996.csv']

# %%
#Notese que los archivos con terminacion _noNan no contienen datos NaN:
dfnonan = pd.read_csv("yearly_files/surveys1977_noNan.csv")

dfnonan
# Out:
#      Unnamed: 0  record_id  month  day  year  plot_id species_id sex  \
# 0            62         63      8   19  1977        3         DM   M
# 1            63         64      8   19  1977        7         DM   M
# 2            64         65      8   19  1977        4         DM   F
# 3            65         66      8   19  1977        4         DM   F
# 4            66         67      8   19  1977        7         DM   M
# ..          ...        ...    ...  ...   ...      ...        ...  ..
# 249         492        493     12   11  1977        4         DS   F
# 250         495        496     12   11  1977       17         DM   F
# 251         497        498     12   11  1977        3         PF   M
# 252         498        499     12   11  1977       11         DS   F
# 253         501        502     12   11  1977        5         DM   F
#
#      hindfoot_length  weight
# 0               35.0    40.0
# 1               37.0    48.0
# 2               34.0    29.0
# ...

# %%
#2  ¿Cómo modificarías el bucle para generar un archivo de datos cada cinco años comenzando desde 1977?

for year in surveys_df['year'].unique():
    año_inicial = surveys_df["year"].unique()[0]
    if year == año_inicial:
        filename='yearly_files/surveys' + str(año_inicial) + '.csv'
        print(filename)
        
    elif (year - surveys_df["year"].unique()[0])%5 == 0:
        filename='yearly_files/surveys' + str(year) + '.csv'
        print(filename)
# Out:
# yearly_files/surveys1977.csv
# yearly_files/surveys1982.csv
# yearly_files/surveys1987.csv
# yearly_files/surveys1992.csv
# yearly_files/surveys1997.csv
# yearly_files/surveys2002.csv

# %%
#3  ¿Cómo escribirías un único archivo CSV por cada especie?

# Load the data into a DataFrame
surveys_df = pd.read_csv('surveys.csv')

for especie in surveys_df['species_id'].unique():
    # Select data for the year
    surveys_specie = surveys_df[surveys_df.species_id == especie]

    # Write the new DataFrame to a CSV file
    filename = 'yearly_files/surveys' + str(especie) + '.csv'
    print(filename)
# Out:
# yearly_files/surveysNL.csv
# yearly_files/surveysDM.csv
# yearly_files/surveysPF.csv
# yearly_files/surveysPE.csv
# yearly_files/surveysDS.csv
# yearly_files/surveysPP.csv
# yearly_files/surveysSH.csv
# yearly_files/surveysOT.csv
# yearly_files/surveysDO.csv
# yearly_files/surveysOX.csv
# yearly_files/surveysSS.csv
# yearly_files/surveysOL.csv
# yearly_files/surveysRM.csv
# yearly_files/surveysnan.csv
# yearly_files/surveysSA.csv
# yearly_files/surveysPM.csv
# yearly_files/surveysAH.csv
# yearly_files/surveysDX.csv
# yearly_files/surveysAB.csv
# yearly_files/surveysCB.csv
# yearly_files/surveysCM.csv
# yearly_files/surveysCQ.csv
# yearly_files/surveysRF.csv
# yearly_files/surveysPC.csv
# yearly_files/surveysPG.csv
# yearly_files/surveysPH.csv
# yearly_files/surveysPU.csv
# yearly_files/surveysCV.csv
# yearly_files/surveysUR.csv
# yearly_files/surveysUP.csv
# yearly_files/surveysZL.csv
# yearly_files/surveysUL.csv
# yearly_files/surveysCS.csv
# yearly_files/surveysSC.csv
# ...

# %% [markdown]
# ## Construyendo código modular y reusable usando funciones
# Comencemos escribiendo una función que separa los datos para un año y los guarda en un archivo:

# %%
def one_year_csv_writer(this_year, all_data):
    """
    Escribe un archivo csv con los datos para un año dado.

    this_year --- el año del que vamos a extraer los datos
    all_data --- DataFrame con datos de múltiples años
    """

    # Seleccionamos los datos para el año
    surveys_year = all_data[all_data.year == this_year]

    # Escribimos el nuevo DataFrame a un archivo csv
    filename = 'yearly_files/function_surveys' + str(this_year) + '.csv'
    surveys_year.to_csv(filename)

# %%
#docstring:
one_year_csv_writer?

# %%
one_year_csv_writer(2002, surveys_df)

# %% [markdown]
# Cambiamos el nombre del archivo CSV para diferenciarlo del que escribimos anteriormente. Busca en el directorio yearly_files el archivo que creamos. ¿Hizo la función lo que esperabas que hiciera?
#
# Sin embargo, lo que nos encantaría hacer es crear archivos para múltiples años sin tener que pedirlos uno a uno. Escribamos otra función que reemplace el bucle for simplemente iterando a través de la secuencia de años y llamando repetidamente a la función que acabamos de escribir, one_year_csv_writer:

# %%
def yearly_data_csv_writer(start_year, end_year, all_data):
    """
    Escribe archivos CSV separados para cada año de datos.

    start_year --- el primer año de datos que queremos
    end_year --- el último año de datos que queremos
    all_data --- DataFrame con datos de varios años
    """

    # "end_year" es el último año que queremos extraer, entonces iteramos hasta end_year+1
    for year in range(start_year, end_year+1):
        one_year_csv_writer(year, all_data)

# %% [markdown]
# Como la gente esperará naturalmente que el año final (end_year) sea el último, el bucle for adentro de la función termina en end_year + 1. Al escribir el bucle entero en la función, hemos hecho una herramienta reusable para cuando necesitemos partir un archivo de datos grande en archivos anuales. Como podemos especificar el primer y el último año para los cuales queremos crear archivos, podemos inclusive usar esta función para crear archivos para un subconjunto de los años disponibles. Así llamaríamos la función:

# %%
# Cargamos los datos en un DataFrame
surveys_df = pd.read_csv('surveys.csv')

# Creamos los archivos CSV
yearly_data_csv_writer(1977, 2002, surveys_df)

# %% [markdown]
# ### Challenge- Más funciones
# 1. Añade dos argumentos a las funciones que escribimos que tomen el path del directorio donde los archivos serán escritos y el root del nombre del archivo. Crea un nuevo conjunto de archivos con un nombre diferente en un directorio diferente.
# 2. ¿Cómo podrías usar la función yearly_data_csv_writer para crear un archivo CSV para solo un año? (Pista: piensa sobre la sintaxis para range)
#
# 3. Haz que las funciones retornen una lista de los archivos que escribieron. Hay muchas formas en las que puedes hacer esto (¡y deberías intentarlas todas!): cualquiera de las dos funciones podría imprimir algo en pantalla, cualquiera podría usar return para retornar números o cadenas de caracteres cada vez que se llaman, o podrías hacer una combinación de estas dos estrategias. Podrías también intentar usar la librería os para listar los contenidos de directorios.
# 4. Explora qué sucede cuando las variables son declaradas dentro de cada una de las funciones versus en el cuerpo principal de tu código (lo que está sin indentar). ¿Cuál es el alcance de las variables (es decir, dónde son visibles)?, ¿qué ocurre si tienen el mismo nombre pero valores diferentes?

# %%
#1 

def one_year_csv_writer(this_year, all_data, directorio):
    """
    Escribe un archivo csv con los datos para un año dado.

    this_year --- el año del que vamos a extraer los datos
    all_data --- DataFrame con datos de múltiples años
    directorio --- la ruta dónde serán escritos los archivos
    """

    # Seleccionamos los datos para el año
    surveys_year = all_data[all_data.year == this_year]

    # Escribimos el nuevo DataFrame a un archivo csv
    filename = directorio+'/function_surveys1' + str(this_year) + '.csv'
    surveys_year.to_csv(filename)
    
    
def yearly_data_csv_writer(start_year, end_year, all_data, directorio):
    """
    Escribe archivos CSV separados para cada año de datos.

    start_year --- el primer año de datos que queremos
    end_year --- el último año de datos que queremos
    all_data --- DataFrame con datos de varios años
    directorio --- la ruta dónde serán escritos los archivos
    """

    # "end_year" es el último año que queremos extraer, entonces iteramos hasta end_year+1
    for year in range(start_year, end_year+1):
        one_year_csv_writer(year, all_data, directorio)

# %%
#2 ¿Cómo podrías usar la función yearly_data_csv_writer para crear un archivo CSV
# para solo un año? (Pista: piensa sobre la sintaxis para range)

yearly_data_csv_writer(1991,1991, surveys_df, "yearly_files")

# %%
#3 Haz que las funciones retornen una lista de los archivos que escribieron. 
# Hay muchas formas en las que puedes hacer esto (¡y deberías intentarlas todas!): cualquiera de las dos 
# funciones podría imprimir algo en pantalla, cualquiera podría usar return para retornar números o cadenas de 
# caracteres cada vez que se llaman, o podrías hacer una combinación de estas dos estrategias. 
# Podrías también intentar usar la librería os para listar los contenidos de directorios.

def one_year_csv_writer(this_year, all_data, directorio):
    """
    Escribe un archivo csv con los datos para un año dado.

    this_year --- el año del que vamos a extraer los datos
    all_data --- DataFrame con datos de múltiples años
    directorio --- la ruta dónde serán escritos los archivos
    """
    lista = []

    # Seleccionamos los datos para el año
    surveys_year = all_data[all_data.year == this_year]

    # Escribimos el nuevo DataFrame a un archivo csv
    filename = directorio+'/function_surveys1' + str(this_year) + '.csv'
    lista.append(filename)
    surveys_year.to_csv(filename)
    return lista
    
    
def yearly_data_csv_writer(start_year, end_year, all_data, directorio):
    """
    Escribe archivos CSV separados para cada año de datos.

    start_year --- el primer año de datos que queremos
    end_year --- el último año de datos que queremos
    all_data --- DataFrame con datos de varios años
    directorio --- la ruta dónde serán escritos los archivos
    """
    lista = []

    # "end_year" es el último año que queremos extraer, entonces iteramos hasta end_year+1
    for year in range(start_year, end_year+1):
        filename = directorio+'/function_surveys1' + str(year) + '.csv'
        lista.append(filename)
        one_year_csv_writer(year, all_data, directorio)
    return lista

yearly_data_csv_writer(1991,2000, surveys_df, "yearly_files")
# Out:
# ['yearly_files/function_surveys11991.csv',
#  'yearly_files/function_surveys11992.csv',
#  'yearly_files/function_surveys11993.csv',
#  'yearly_files/function_surveys11994.csv',
#  'yearly_files/function_surveys11995.csv',
#  'yearly_files/function_surveys11996.csv',
#  'yearly_files/function_surveys11997.csv',
#  'yearly_files/function_surveys11998.csv',
#  'yearly_files/function_surveys11999.csv',
#  'yearly_files/function_surveys12000.csv']

# %%
#4

"Las variables definidas dentro de una función no afectan a las variables fuera de esta."
# Out:
# 'Las variables definidas dentro de una función no afectan a las variables fuera de esta.'

# %% [markdown]
# ### Funciones con argumentos definidos por defecto
#
# Las funciones que escribimos exigen que les demos un valor para cada argumento. Idealmente, nos gustaría que estas funciones fuesen tan flexibles e independientes como fuera posible. Modifiquemos la función yearly_data_csv_writer para que start_year y end_year sean por defecto el rango completo de los datos si no son dados por el usuario. Se le pueden asignar a los argumentos valores por defecto usando el signo igual a la hora de declarar la función. Todos los argumentos en la función que no tengan un valor por defecto (como aquí all_data) serán argumentos requeridos y DEBERÁN ir antes de los argumentos que tengan valores por defecto (y que son opcionales al llamar la función).

# %%
def yearly_data_arg_test(all_data, start_year = 1977, end_year = 2002):
    """
    Modificación de yearly_data_csv_writer para probar argumentos con valores
    por defecto!

    start_year --- el primer año de datos que queremos --- por defecto: 1977
    end_year --- el último año de datos que queremos --- por defecto: 2002
    all_data --- DataFrame con datos de varios años
    """

    return start_year, end_year


start,end = yearly_data_arg_test (surveys_df, 1988, 1993)
print('Both optional arguments:\t', start, end)

start,end = yearly_data_arg_test (surveys_df)
print('Default values:\t\t\t', start, end)
# Out:
# Both optional arguments:	 1988 1993
# Default values:			 1977 2002

# %% [markdown]
# Los “\t” en print son tabulaciones, y son usadas para alinear el texto y facilitar la lectura.
#
# Pero ¿qué sucede si nuestro dataset no comienza en 1977 ni termina en 2002? Podemos modificar la función de tal forma que ella misma mire cuál es el primer y cuál es el último año si estos argumentos no son provistos por el usuario:

# %%
def yearly_data_arg_test(all_data, start_year = None, end_year = None):
    """
    Modificación de yearly_data_csv_writer para probar argumentos con valores
    por defecto!

    start_year --- el primer año de datos que queremos --- por defecto: None - revisar all_data
    end_year --- el último año de datos que queremos --- por defecto: None - revisar all_data
    all_data --- DataFrame con datos de varios años
    """

    if start_year is None:
        start_year = min(all_data.year)
    if end_year is None:
        end_year = max(all_data.year)

    return start_year, end_year


start,end = yearly_data_arg_test (surveys_df, 1988, 1993)
print('Both optional arguments:\t', start, end)

start,end = yearly_data_arg_test (surveys_df)
print('Default values:\t\t\t', start, end)
# Out:
# Both optional arguments:	 1988 1993
# Default values:			 1977 2002

# %% [markdown]
# Ahora los valores por defecto de los argumentos start_year y end_year en la función yearly_data_arg_test son None. Esta es una constante incorporada en Python que indica la ausencia de un valor - esencialmente indica que la variable existe en el directorio de nombres de variables (el namespace) de la función pero que no corresponde a ningún objeto existente.

# %% [markdown]
# ### Challenge - Variables
# 1. ¿Qué tipo de objeto corresponde a una variable declarada como None? (Pista: crea una variable con el valor None y usa la función type())
#
# 2. Compara el comportamiento de la función yearly_data_arg_test cuando los argumentos tienen None como valor por defecto y cuando no tienen valores por defecto.
#
# 3. ¿Qué ocurre si solo incluimos un valor para start_year al llamar a la función?, ¿puedes escribir una llamada a la función con solo un valor para end_year? (Pista: piensa en cómo la función debe estar asignándole valores a cada uno de sus argumentos - ¡esto está relacionado con la necesidad de poner los argumentos que no tienen valores por defecto antes de los que sí tienen valores por defecto en la definición de la función!)

# %%
#1 
non = None 
type(non)
# Out:
# NoneType

# %%
#2 
"""Si la función no tiene a None como valor por defecto , al llamar la función y no especificar los valores de los argumentos,
ocurrira un error , ya que la función NECESITA valores para sus argumentos. En caso contrario, al definir None como valor 
por defecto, no ocurrira error """
# Out:
# 'Si la función no tiene a None como valor por defecto , al llamar la función y no especificar los valores de los argumentos,\nocurrira un error , ya que la función NECESITA valores para sus argumentos. En caso contrario, al definir None como valor \npor defecto, no ocurrira error '

# %% [markdown]
# ## Sentencias if
#
# El cuerpo de la función anterior ahora tiene dos condicionales if que revisan los valores de start_year y end_year. Los condicionales if ejecutan un segmento de código si una condición dada es cierta.
#
# Los condicionales if en la función yearly_data_arg_test verifican si hay algún objeto asociado a los nombres start_year y end_year. Si estas variables son None, los condicionales if retornan el booleano True y ejecutan cualquier cosa que esté en su cuerpo. Por otra parte, si los nombres están asociados a algún valor (es decir, recibieron un número al ser llamada la función), los condicionales if retornarán False y no ejecutan su cuerpo. El condicional opuesto, que retornaría True si las variables estuvieran asociadas con objetos (es decir, si hubieran recibido valores al llamarse la función), sería if start_year y if end_year.
#
# Tal y como la hemos escrito hasta este momento, la función yearly_data_arg_test asocia los valores que le pasamos cuando la llamamos con los argumentos en la definición de la función solo basados en su orden. Si la función recibe solo dos valores al ser llamada, el primero será asociado con all_data y el segundo con start_year, sin importar cuál era nuestra intención. Podemos solucionar este problema al llamar la función usando argumentos keyword, en donde cada uno de los argumentos en la definición de la función está asociado con una keyword y al llamar la función pasamos valores a los parámetros usando estas keywords:

# %% [markdown]
# ### Desafío - Modificando funciones
# 1. Reescribe las funciones one_year_csv_writer y yearly_data_csv_writer para que tengan argumentos keyword con valores por defecto.
#
# 2. Modifica las funciones de tal forma que no creen archivos para un año si éste no está en los datos y que muestre una alerta al usuario (Pista: usa condicionales para esto. Si quieres un reto más, ¡usa try!)
#
# 3. Este código verifica si un directorio existe, sino lo crea. Añade un poco de código a la función que escribe los archivos CSV para verificar si existe el directorio al que piensas escribir.

# %%
#1 
def one_year_csv_writer(this_year, all_data, directorio):
    """
    Escribe un archivo csv con los datos para un año dado.

    this_year --- el año del que vamos a extraer los datos
    all_data --- DataFrame con datos de múltiples años
    directorio --- la ruta dónde serán escritos los archivos
    """
    lista = []

    # Seleccionamos los datos para el año
    surveys_year = all_data[all_data.year == this_year]

    # Escribimos el nuevo DataFrame a un archivo csv
    filename = directorio+'/function_surveys1' + str(this_year) + '.csv'
    lista.append(filename)
    surveys_year.to_csv(filename)
    return lista
    
    
def yearly_data_csv_writer(start_year, end_year, all_data, directorio):
    """
    Escribe archivos CSV separados para cada año de datos.

    start_year --- el primer año de datos que queremos
    end_year --- el último año de datos que queremos
    all_data --- DataFrame con datos de varios años
    directorio --- la ruta dónde serán escritos los archivos
    """
    lista = []

    # "end_year" es el último año que queremos extraer, entonces iteramos hasta end_year+1
    for year in range(start_year, end_year+1):
        filename = directorio+'/function_surveys1' + str(year) + '.csv'
        lista.append(filename)
        one_year_csv_writer(year, all_data, directorio)
    return lista
