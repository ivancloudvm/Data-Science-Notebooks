# %% [markdown]
# ivancloudvm@gmail.com
# # Proyecto Mushrooms [Kaggle Dataset](https://www.kaggle.com/uciml/mushroom-classification)

# %% [markdown]
# ### Importamos librerias:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#modelos
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ### Extraemos datos:

# %%
datos = pd.read_csv(r"C:\Users\sephc\mushrooms_data\mushrooms.csv")

datos
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# ### Veamos todas las features:

# %%
datos.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# ### Vizualicemos el número de hongos que caen en cada clase donde p = venenoso , e = comestible

# %%
#estilo y tamaño del plot:
plt.style.use('dark_background')
plt.rcParams['figure.figsize']=8,8 

#construimos un countplot
s = sns.countplot(x = "class", data = datos)

for p in s.patches:
    s.annotate(format(p.get_height(), '.1f'), 
               (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')
plt.show()

# %% [markdown]
# Construimos un diccionario donde a cada letra le asignamos un numero, esto para trabajar con números en vez de letras:

# %%
mapeos = []

encoder = LabelEncoder()    # Encode target labels with value between 0 and n_classes-1

for column in range(len(datos.columns)):
    #a cada entrada del df le asigna un valor de 0 a n-1 donde n es el numero de clases distintas en cada columna
    datos[datos.columns[column]] = encoder.fit_transform(datos[datos.columns[column]]) 
    mappings_dict = {index: label for index, label in enumerate(encoder.classes_)}
    mapeos.append(mappings_dict)

# %%
mapeos
# Out:
# [{0: 'e', 1: 'p'},
#  {0: 'b', 1: 'c', 2: 'f', 3: 'k', 4: 's', 5: 'x'},
#  {0: 'f', 1: 'g', 2: 's', 3: 'y'},
#  {0: 'b',
#   1: 'c',
#   2: 'e',
#   3: 'g',
#   4: 'n',
#   5: 'p',
#   6: 'r',
#   7: 'u',
#   8: 'w',
#   9: 'y'},
#  {0: 'f', 1: 't'},
#  {0: 'a', 1: 'c', 2: 'f', 3: 'l', 4: 'm', 5: 'n', 6: 'p', 7: 's', 8: 'y'},
#  {0: 'a', 1: 'f'},
#  {0: 'c', 1: 'w'},
#  {0: 'b', 1: 'n'},
#  {0: 'b',
#   1: 'e',
#   2: 'g',
#   3: 'h',
#   4: 'k',
#   5: 'n',
#   6: 'o',
#   7: 'p',
#   8: 'r',
#   9: 'u',
#   10: 'w',
#   11: 'y'},
#  {0: 'e', 1: 't'},
#  {0: '?', 1: 'b', 2: 'c', 3: 'e', 4: 'r'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'p'},
#  {0: 'n', 1: 'o', 2: 'w', 3: 'y'},
#  {0: 'n', 1: 'o', 2: 't'},
#  {0: 'e', 1: 'f', 2: 'l', 3: 'n', 4: 'p'},
# ...

# %%
datos
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
y = datos["class"]
X = datos.drop("class", axis = 1)

# %%
scaler = StandardScaler()

X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color   bruises      odor  gill-attachment  \
# 0      1.029712     0.140128  -0.198250  1.185917  0.881938         0.162896
# 1      1.029712     0.140128   1.765874  1.185917 -1.970316         0.162896
# 2     -2.087047     0.140128   1.373049  1.185917 -0.544189         0.162896
# 3      1.029712     0.953270   1.373049  1.185917  0.881938         0.162896
# 4      1.029712     0.140128  -0.591075 -0.843230  0.406562         0.162896
# ...         ...          ...        ...       ...       ...              ...
# 8119  -0.216992     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8120   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8121  -0.840343     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8122  -0.216992     0.953270  -0.198250 -0.843230  1.832689         0.162896
# 8123   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8)

# %% [markdown]
# MODEL

# %%
log_model = LogisticRegression()
svm_model = SVC(C=1.0, kernel ="rbf")
nn_model = MLPClassifier(hidden_layer_sizes=(128,128))

# %% [markdown]
# Training
#
# Observemos que la precision es buena metrica en este caso ya que el porcentaje de datos positivos (class = 1) esta balanceado con el numero de casos negativos(class = 0 ). Podemos ver esto de la siguiente manera:

# %%
print("Porcentaje de datos positivos: ", np.sum(y)/ len(y) *100,"%")
print("Porcentaje de datos negativos: ", 100 - np.sum(y)/ len(y) *100, "%")
# Out:
# Porcentaje de datos positivos:  48.20285573609059 %
# Porcentaje de datos negativos:  51.79714426390941 %

# %%
log_model.fit(x_train, y_train)
svm_model.fit(x_train, y_train)
nn_model.fit(x_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(128, 128))

# %%
print(f"---Regresion Logistica: {log_model.score(x_test, y_test)}")
print(f"Support Vector Machine: {svm_model.score(x_test, y_test)}")
print(f"--------Neural Network: {nn_model.score(x_test, y_test)}")
# Out:
# ---Regresion Logistica: 0.9495384615384616
# Support Vector Machine: 1.0
# --------Neural Network: 1.0

# %% [markdown]
# Vizualizacion

# %%
x_test.shape
# Out:
# (1625, 22)

# %%
corr = datos.corr()
corr
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>
